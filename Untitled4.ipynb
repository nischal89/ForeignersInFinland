# %%
import plotly.plotly as py

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/Nischal/Documents/capstone/foreigners.csv", sep=',', encoding='latin-1')
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Numbers and shares of persons with immigrant background by area 1990-2017
# ...

# %%
df = pd.read_csv("/Users/Nischal/Documents/capstone/foreigners2017.csv", sep=',', encoding='latin-1')
df.head(10)
# Out:
#             Area  Foreigners        lat        lon
# 0  WHOLE COUNTRY      249452        NaN        NaN
# 1           Akaa         261  61.166667  23.866667
# 2       Alaj_rvi         189  63.000000  23.816667
# 3      Alavieska          16        NaN        NaN
# 4         Alavus         130        NaN        NaN
# 5       Asikkala         136        NaN        NaN
# 6         Askola          89        NaN        NaN
# 7           Aura          88        NaN        NaN
# 8         Br_nd_          38        NaN        NaN
# 9         Ecker_         109        NaN        NaN

# %%
df['text'] = df['Area'] + '<br>immigrants ' + (df["Foreigners"]).astype(str)

# %%
limits = [(0,2),(3,10),(11,20),(21,50),(50,3000)]
colors = ["rgb(0,116,217)","rgb(255,65,54)","rgb(133,20,75)","rgb(255,133,27)","lightgrey"]
cities = []
scale = 5000

# %%
for i in range(len(limits)):
    lim = limits[i]
    df_sub = df[lim[0]:lim[1]]
    city = dict(
        type = 'scattergeo',
        locationmode = 'Finland',
        lon = df_sub['lon'],
        lat = df_sub['lat'],
        text = df_sub['text'],
        marker = dict(
            size = df_sub['Foreigners']/scale,
            # sizeref = 2. * max(df_sub['pop']/scale) / (25 ** 2),
            color = colors[i],
            line = dict(width=0.5, color='rgb(40,40,40)'),
            sizemode = 'area'
        ),
        name = '{0} - {1}'.format(lim[0],lim[1]) )
    cities.append(city)layout = dict(
title = '2014 US city populations<br>(Click legend to toggle traces)',
        showlegend = True,
        geo = dict(
            scope='finland',
            projection=dict( type='albers usa' ),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
        ),
    )

fig = dict(data=cities, layout=layout)
py.iplot(fig, validate=False, filename='d3-bubble-map-populations')
# Out:
#   File "<ipython-input-40-d20ce0b12856>", line 18
#     cities.append(city)layout = dict(
#                             ^
# SyntaxError: invalid syntax
